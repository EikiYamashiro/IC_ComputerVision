# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print ("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 4.4.0

# %%
#A imagem é aberta em BGR...
image = cv2.imread("arara_medium.jpg")
#Convertendo BGR para RGB:
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
#Plotando a imagem em RGB:
plt.imshow(image_rgb)

# %%
#A imagem_rgb consiste em um conjunto de pixels que são listas [R,G,B]
type(image_rgb)
# Out:
# numpy.ndarray

# %%
#rows: quantidade de pixels no eixo y
#columns: quantidade de pixels no eixo x
#channels: número de canais

rows, columns, channels = image_rgb.shape

# %% [markdown]
# Cada pixel terá um codebook que é representado por n Codewords. Cada codeword consiste em um vetor [R,G,B] e uma 6-tupple:

# %% [markdown]
# 6-tuple = {l_max, l_min, f, MNRL, first, last}

# %%
#Mínimo brilho de todos os pixels atríbuidos para esse codeword:
l_max = 0
#Máximo brilho de todos os pixels atríbuidos para esse codeword:
l_min = 0
#Frequência em que cada codeword ocorre:
f = 0
#Maior intervalo durante o período de treinamento em que o codeword não foi recorrente:
MNRL = 0
#Primeiro tempo de acesso:
first = 0
#Último tempo de acesso:
last = 0

#6-tupple, possui todas as variáveis acima:
six_tupple = [l_max, l_min, f, MNRL, first, last]

# %%
image_list = []
for row in range(0, rows):
    image_list.append(image_rgb[row])
